# %% [markdown]
# ## Limpieza de datos

# %% [markdown]
# Librerías

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# Carga de datos

# %%
# Cargar el archivo Excel
archivo = 'Datos_Filtrados.xlsx'
df = pd.read_excel(archivo)

# %%
# Mostrar el DataFrame
print(df.head(5))
# Out:
#    PERIODO ESTU_TIPODOCUMENTO  ESTU_CONSECUTIVO COLE_AREA_UBICACION  \
# 0    20194                 TI  SB11201940226736              URBANO
# 1    20194                 TI  SB11201940226736              URBANO
# 2    20194                 CC  SB11201940041980              URBANO
# 3    20194                 CC  SB11201940041980              URBANO
# 4    20194                 TI  SB11201940356965               RURAL
#
#   COLE_BILINGUE COLE_CALENDARIO        COLE_CARACTER  \
# 0             N               A  TÃ‰CNICO/ACADÃ‰MICO
# 1             N               A  TÃ‰CNICO/ACADÃ‰MICO
# 2             N               A             TÃ‰CNICO
# 3             N               A             TÃ‰CNICO
# 4             N               A           ACADÃ‰MICO
#
#    COLE_COD_DANE_ESTABLECIMIENTO  COLE_COD_DANE_SEDE  \
# 0                   168001002421        168001002421
# 1                   168001002421        168001002421
# 2                   168298000235        168298000235
# ...

# %%
#Ver nombres columnas
print(df.columns)
# Out:
# Index(['PERIODO', 'ESTU_TIPODOCUMENTO', 'ESTU_CONSECUTIVO',
#        'COLE_AREA_UBICACION', 'COLE_BILINGUE', 'COLE_CALENDARIO',
#        'COLE_CARACTER', 'COLE_COD_DANE_ESTABLECIMIENTO', 'COLE_COD_DANE_SEDE',
#        'COLE_COD_DEPTO_UBICACION', 'COLE_COD_MCPIO_UBICACION',
#        'COLE_CODIGO_ICFES', 'COLE_DEPTO_UBICACION', 'COLE_GENERO',
#        'COLE_JORNADA', 'COLE_MCPIO_UBICACION', 'COLE_NATURALEZA',
#        'COLE_NOMBRE_ESTABLECIMIENTO', 'COLE_NOMBRE_SEDE',
#        'COLE_SEDE_PRINCIPAL', 'ESTU_COD_DEPTO_PRESENTACION',
#        'ESTU_COD_MCPIO_PRESENTACION', 'ESTU_COD_RESIDE_DEPTO',
#        'ESTU_COD_RESIDE_MCPIO', 'ESTU_DEPTO_PRESENTACION', 'ESTU_DEPTO_RESIDE',
#        'ESTU_ESTADOINVESTIGACION', 'ESTU_ESTUDIANTE', 'ESTU_FECHANACIMIENTO',
#        'ESTU_GENERO', 'ESTU_MCPIO_PRESENTACION', 'ESTU_MCPIO_RESIDE',
#        'ESTU_NACIONALIDAD', 'ESTU_PAIS_RESIDE', 'ESTU_PRIVADO_LIBERTAD',
#        'FAMI_CUARTOSHOGAR', 'FAMI_EDUCACIONMADRE', 'FAMI_EDUCACIONPADRE',
# ...

# %%
#Eliminar columnas irrelevantes

columnas_quitar = [
    'ESTU_TIPODOCUMENTO', 'ESTU_CONSECUTIVO', 'COLE_COD_DANE_ESTABLECIMIENTO',
    'COLE_COD_DANE_SEDE', 'COLE_COD_DEPTO_UBICACION', 'COLE_COD_MCPIO_UBICACION',
    'COLE_CODIGO_ICFES', 'ESTU_COD_DEPTO_PRESENTACION', 'ESTU_COD_MCPIO_PRESENTACION',
    'ESTU_COD_RESIDE_DEPTO', 'ESTU_COD_RESIDE_MCPIO', 'ESTU_PAIS_RESIDE',
    'ESTU_NACIONALIDAD', 'ESTU_FECHANACIMIENTO', 'ESTU_MCPIO_RESIDE',
    'ESTU_MCPIO_PRESENTACION', 'COLE_SEDE_PRINCIPAL', 'ESTU_DEPTO_PRESENTACION',
    'ESTU_DEPTO_RESIDE', 'ESTU_ESTADOINVESTIGACION', 'ESTU_ESTUDIANTE'
]

# Eliminar las columnas seleccionadas
df = df.drop(columns=columnas_quitar)

# %%
print(df.head(5))
# Out:
#    PERIODO COLE_AREA_UBICACION COLE_BILINGUE COLE_CALENDARIO  \
# 0    20194              URBANO             N               A
# 1    20194              URBANO             N               A
# 2    20194              URBANO             N               A
# 3    20194              URBANO             N               A
# 4    20194               RURAL             N               A
#
#          COLE_CARACTER COLE_DEPTO_UBICACION COLE_GENERO COLE_JORNADA  \
# 0  TÃ‰CNICO/ACADÃ‰MICO            SANTANDER       MIXTO      MAÃ‘ANA
# 1  TÃ‰CNICO/ACADÃ‰MICO            SANTANDER       MIXTO      MAÃ‘ANA
# 2             TÃ‰CNICO            SANTANDER       MIXTO      MAÃ‘ANA
# 3             TÃ‰CNICO            SANTANDER       MIXTO      MAÃ‘ANA
# 4           ACADÃ‰MICO            SANTANDER       MIXTO      MAÃ‘ANA
#
#   COLE_MCPIO_UBICACION COLE_NATURALEZA  ... FAMI_TIENECOMPUTADOR  \
# 0          BUCARAMANGA         OFICIAL  ...                   Si
# ...

# %%
print(df.columns)
# Out:
# Index(['PERIODO', 'COLE_AREA_UBICACION', 'COLE_BILINGUE', 'COLE_CALENDARIO',
#        'COLE_CARACTER', 'COLE_DEPTO_UBICACION', 'COLE_GENERO', 'COLE_JORNADA',
#        'COLE_MCPIO_UBICACION', 'COLE_NATURALEZA',
#        'COLE_NOMBRE_ESTABLECIMIENTO', 'COLE_NOMBRE_SEDE', 'ESTU_GENERO',
#        'ESTU_PRIVADO_LIBERTAD', 'FAMI_CUARTOSHOGAR', 'FAMI_EDUCACIONMADRE',
#        'FAMI_EDUCACIONPADRE', 'FAMI_ESTRATOVIVIENDA', 'FAMI_PERSONASHOGAR',
#        'FAMI_TIENEAUTOMOVIL', 'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET',
#        'FAMI_TIENELAVADORA', 'DESEMP_INGLES', 'PUNT_INGLES',
#        'PUNT_MATEMATICAS', 'PUNT_SOCIALES_CIUDADANAS', 'PUNT_C_NATURALES',
#        'PUNT_LECTURA_CRITICA', 'PUNT_GLOBAL'],
#       dtype='object')

# %% [markdown]
# Revisar valores únicos

# %%
for column in df.columns:
    unique_values = df[column].unique()
    print(f"{column}: {unique_values}\n")
# Out:
# PERIODO: [20194 20221 20224 20201 20211 20191]
#
# COLE_AREA_UBICACION: ['URBANO' 'RURAL']
#
# COLE_BILINGUE: ['N' nan 'S']
#
# COLE_CALENDARIO: ['A' 'OTRO' 'B']
#
# COLE_CARACTER: ['TÃ‰CNICO/ACADÃ‰MICO' 'TÃ‰CNICO' 'ACADÃ‰MICO' nan 'NO APLICA']
#
# COLE_DEPTO_UBICACION: ['SANTANDER' 'NORTE SANTANDER']
#
# COLE_GENERO: ['MIXTO' 'FEMENINO' 'MASCULINO']
#
# COLE_JORNADA: ['MAÃ‘ANA' 'UNICA' 'TARDE' 'COMPLETA' 'SABATINA' 'NOCHE']
#
# COLE_MCPIO_UBICACION: ['BUCARAMANGA' 'GÃ\x81MBITA' 'CHARALÃ\x81' 'VILLA DEL ROSARIO'
#  'FLORIDABLANCA' 'GIRÃ“N' 'CURITÃ\x8d' 'RIONEGRO' 'LEBRIJA' 'CÃšCUTA'
#  'SABANA DE TORRES' 'OCAÃ‘A' 'PIEDECUESTA' 'LABATECA'
#  'SAN VICENTE DE CHUCURÃ\x8d' 'MÃ\x81LAGA' 'SOCORRO' 'TIBÃš' 'ARATOCA'
#  'PUERTO PARRA' 'BARRANCABERMEJA' 'CÃ\x81CHIRA' 'ZAPATOCA' 'OIBA'
#  'PUERTO WILCHES' 'SURATÃ\x81' 'SAN ANDRÃ‰S' 'Ã\x81BREGO' 'BOLÃ\x8dVAR'
#  'LA ESPERANZA' 'PÃ\x81RAMO' 'BARICHARA' 'EL TARRA' 'SILOS' 'PAMPLONA'
# ...

# %% [markdown]
# Arreglar valores

# %%
# Corregir los valores en la columna 'PERIODO'
df['PERIODO'] = df['PERIODO'].replace({20224: 20222, 20194: 20192})

# Verificar los valores únicos en la columna 'PERIODO' después de la corrección
print(df['PERIODO'].unique())
# Out:
# [20192 20221 20222 20201 20211 20191]

# %%
# Reemplazar valores nan por 'N' en la columna 'COLE_BILINGUE' si el colegio está en un área rural
df.loc[(df['COLE_BILINGUE'].isna()) & (df['COLE_AREA_UBICACION'] == 'Rural'), 'COLE_BILINGUE'] = 'N'

# Eliminar filas restantes con valores nan en la columna 'COLE_BILINGUE'
df = df.dropna(subset=['COLE_BILINGUE'])

# Verificar los valores únicos en la columna 'COLE_BILINGUE' después de la corrección
print(df['COLE_BILINGUE'].unique())
# Out:
# ['N' 'S']

# %%
num_rows = df.shape[0]
print(f"Número de filas: {num_rows}")
# Out:
# Número de filas: 141482

# %%
# Corregir la codificación de caracteres
df['COLE_CARACTER'] = df['COLE_CARACTER'].replace({
    'TÃ‰CNICO/ACADÃ‰MICO': 'TÉCNICO/ACADÉMICO',
    'TÃ‰CNICO': 'TÉCNICO',
    'ACADÃ‰MICO': 'ACADÉMICO'
})

# Eliminar filas con valores nan en la columna 'COLE_CARACTER'
df = df.dropna(subset=['COLE_CARACTER'])

# Verificar los valores únicos después de eliminar nulos
print("Valores únicos después de eliminar nulos:", df['COLE_CARACTER'].unique())
# Out:
# Valores únicos después de eliminar nulos: ['TÉCNICO/ACADÉMICO' 'TÉCNICO' 'ACADÉMICO' 'NO APLICA']

# %%
num_rows = df.shape[0]
print(f"Número de filas: {num_rows}")
# Out:
# Número de filas: 141482

# %%
df = df[df['COLE_CALENDARIO'] != 'OTRO']
print("Valores únicos", df['COLE_CALENDARIO'].unique())
# Out:
# Valores únicos ['A' 'B']

# %%
num_rows = df.shape[0]
print(f"Número de filas: {num_rows}")
# Out:
# Número de filas: 141422

# %%
df['COLE_JORNADA'] = df['COLE_JORNADA'].replace({
    'MAÃ‘ANA': 'MAÑANA',
    'UNICA': 'ÚNICA',
})

# Verificar los valores únicos en 'COLE_JORNADA' después de la corrección
print("Valores únicos en después de la corrección:", df['COLE_JORNADA'].unique())
# Out:
# Valores únicos en después de la corrección: ['MAÑANA' 'ÚNICA' 'TARDE' 'COMPLETA' 'SABATINA' 'NOCHE']

# %%
replacements = {
    'GÃ\x81MBITA': 'GÁMBITA',
    'CHARALÃ\x81': 'CHARALÁ',
    'CURITÃ\x8d': 'CURITÍ',
    'CÃšCUTA': 'CÚCUTA',
    'GIRÃ“N': 'GIRÓN',
    'SAN VICENTE DE CHUCURÃ\x8d': 'SAN VICENTE DE CHUCURÍ',
    'MÃ\x81LAGA': 'MÁLAGA',
    'TIBÃš': 'TIBÚ',
    'CÃ\x81CHIRA': 'CÁCHIRA',
    'Ã\x81BREGO': 'ÁBREGO',
    'BOLÃ\x8dVAR': 'BOLÍVAR',
    'PÃ\x81RAMO': 'PÁRAMO',
    'SANTA BÃ\x81RBARA': 'SANTA BÁRBARA',
    'CHINÃ\x81COTA': 'CHINÁCOTA',
    'GÃœEPSA': 'GÜEPSA',
    'CONCEPCIÃ“N': 'CONCEPCIÓN',
    'EL CARMEN DE CHUCURÃ\x8d': 'EL CARMEN DE CHUCURÍ',
    'VALLE DE SAN JOSÃ‰': 'VALLE DE SAN JOSÉ',
    'CARCASÃ\x8d': 'CARCASÍ',
    'VÃ‰LEZ': 'VÉLEZ',
    'GALÃ\x81N': 'GALÁN',
    'CHITAGÃ\x81': 'CHITAGÁ',
    'GUAPOTÃ\x81': 'GUAPOTÁ',
    'HERRÃ\x81N': 'HERRÁN',
    'FLORIÃ\x81N': 'FLORIÁN',
    'CHIPATÃ\x81': 'CHIPATÁ',
    'CÃ\x81COTA': 'CÁCOTA',
    'EL PEÃ‘Ã“N': 'EL PEÑÓN',
    'JESÃšS MARÃ\x8dA': 'JESÚS MARÍA',
    'BUCARASICA': 'BUCARASICA',
    'HACARÃ\x8d': 'HACARÍ',
    'SAN JOAQUÃ\x8dN': 'SAN JOAQUÍN',
    'OCAMONTE': 'OCAMONTE',
    'MUTISCUA': 'MUTISCUA',
    'SANTA HELENA DEL OPÃ“N': 'SANTA HELENA DEL OPÓN',
    'GUACA': 'GUACA',
    'SAN JOSÃ‰ DE MIRANDA': 'SAN JOSÉ DE MIRANDA',
    'CEPITÃ\x81': 'CEPITÁ',
    'JORDÃ\x81N': 'JORDÁN',
    'EL PLAYÃ“N': 'EL PLAYÓN',
    'VILLA DEL ROSARIO': 'VILLA DEL ROSARIO',
    'LEBRIJA': 'LEBRIJA'
    # Agregar más reemplazos si es necesario
}

# Reemplazar los valores mal codificados
df['COLE_MCPIO_UBICACION'] = df['COLE_MCPIO_UBICACION'].replace(replacements)

# Verificar los valores únicos después de la corrección
print("Valores únicos en 'COLE_MCPIO_UBICACION' después de la corrección:", df['COLE_MCPIO_UBICACION'].unique())

# Verificar el número de filas después de todas las correcciones
# Out:
# Valores únicos en 'COLE_MCPIO_UBICACION' después de la corrección: ['BUCARAMANGA' 'GÁMBITA' 'CHARALÁ' 'VILLA DEL ROSARIO' 'FLORIDABLANCA'
#  'CURITÍ' 'GIRÓN' 'RIONEGRO' 'LEBRIJA' 'CÚCUTA' 'OCAÃ‘A' 'LABATECA'
#  'SAN VICENTE DE CHUCURÍ' 'MÁLAGA' 'SOCORRO' 'TIBÚ' 'ARATOCA'
#  'PUERTO PARRA' 'BARRANCABERMEJA' 'CÁCHIRA' 'PIEDECUESTA' 'ZAPATOCA'
#  'OIBA' 'PUERTO WILCHES' 'SAN ANDRÃ‰S' 'ÁBREGO' 'BOLÍVAR' 'LA ESPERANZA'
#  'PÁRAMO' 'BARICHARA' 'EL TARRA' 'SILOS' 'PAMPLONA' 'RAGONVALIA'
#  'SANTA BÁRBARA' 'TEORAMA' 'LOS PATIOS' 'CHINÁCOTA' 'TOLEDO' 'PINCHOTE'
#  'AGUADA' 'SAN GIL' 'PUENTE NACIONAL' 'GÜEPSA' 'CUCUTILLA' 'VILLANUEVA'
#  'CONCEPCIÓN' 'SALAZAR' 'ARBOLEDAS' 'BARBOSA' 'SUAITA' 'GRAMALOTE'
#  'GUAVATÃ\x81' 'EL CARMEN DE CHUCURÍ' 'SARDINATA' 'LANDÃ\x81ZURI'
#  'CONVENCIÃ“N' 'BOCHALEMA' 'VALLE DE SAN JOSÉ' 'SIMACOTA' 'EL ZULIA'
#  'EL CARMEN' 'GALÁN' 'TONA' 'CIMITARRA' 'CHITAGÁ' 'GUAPOTÁ' 'CARCASÍ'
#  'DURANIA' 'COROMORO' 'CHARTA' 'CAPITANEJO' 'LA PAZ' 'CHIMA' 'ENCISO'
# ...

# %%
# Diccionario de reemplazos para corregir la codificación en 'COLE_NOMBRE_ESTABLECIMIENTO'
replacements = {
    'IE NUESTRA SEÃ‘ORA DEL PILAR': 'IE NUESTRA SEÑORA DEL PILAR',
    'COLEGIO MUNICIPAL MARÃ\x8dA CONCEPCIÃ“N LOPERENA.': 'COLEGIO MUNICIPAL MARÍA CONCEPCIÓN LOPERENA',
    'INST TECNICO INDUSTRIAL LUCIO PABON NUÃ‘EZ': 'INST TECNICO INDUSTRIAL LUCIO PABON NUÑEZ',
    'COL INTEGRADO NUESTRA SEÂ¿ORA DE LAS ANGUSTIAS': 'COL INTEGRADO NUESTRA SEÑORA DE LAS ANGUSTIAS',
    'INSTITUTO POLITECNICO MONSEÂ¿OR MANUEL SORZANO GONZALEZ': 'INSTITUTO POLITECNICO MONSEÑOR MANUEL SORZANO GONZALEZ',
    'COLEGIO SAN JOSÃ‰ DE MOTOSO': 'COLEGIO SAN JOSÉ DE MOTOSO',
    'INSTITUCIÃ“N EDUCATIVA CLAVELLINAS': 'INSTITUCIÓN EDUCATIVA CLAVELLINAS',
    'INST NAL DE ENSEÂ¿ANZA MEDIA DIVERSIFICADA INEM JOSE EUSEBIO CARO': 'INST NAL DE ENSEÑANZA MEDIA DIVERSIFICADA INEM JOSE EUSEBIO CARO',
    'INST TEC MERCEDES ABREGO': 'INST TEC MERCEDES ÁBREGO',
    'INST EDUCATIVA COL SAGRADO CORAZON DE JESUS': 'INST EDUCATIVA COL SAGRADO CORAZÓN DE JESUS',
    'I.E. PARA JÃ“VENES Y ADULTOS SIN FRONTERAS': 'I.E. PARA JÓVENES Y ADULTOS SIN FRONTERAS',
    'COLEGIO FRANCISCO SAN JUAN': 'COLEGIO FRANCISCO SAN JUAN',
    'INST BILINGÂ¿E LONDRES': 'INST BILINGÜE LONDRES',
    'I E CLUB UNION': 'I E CLUB UNIÓN',
    'INST EDUCATIVA CLAVERIANO FE Y ALEGRIA': 'INST EDUCATIVA CLAVERIANO FE Y ALEGRÍA',
    'INSTITUCION EDUCATIVA GABRIELA MISTRAL': 'INSTITUCIÓN EDUCATIVA GABRIELA MISTRAL',
    'COLEGIO NUESTRA SEÂ¿ORA DE LA MERCED': 'COLEGIO NUESTRA SEÑORA DE LA MERCED',
    'INST TEC NAL DE COMERCIO': 'INST TEC NAL DE COMERCIO',
    'INSTITUCION EDUCTIVA MPAL CAMILO TORRES RESTREPO': 'INSTITUCIÓN EDUCATIVA MPAL CAMILO TORRES RESTREPO',
    'INST AGRICOLA REGION DEL CATATUMBO': 'INST AGRÍCOLA REGIÓN DEL CATATUMBO',
    'INST EDUCATIVO NOCTURNO FE CULTURA PIEDAD Y LETRAS': 'INST EDUCATIVO NOCTURNO FE CULTURA PIEDAD Y LETRAS',
    'INST SALESIANO SAN JUAN BOSCO': 'INST SALESIANO SAN JUAN BOSCO',
    'IE TEC INEM CUSTODIO GARCÃ\x8dA ROVIRA': 'IE TEC INEM CUSTODIO GARCÍA ROVIRA',
    'INSTITUCIÃ“N EDUCATIVA AURELIO MARTÃ\x8dNEZ MUTIS': 'INSTITUCIÓN EDUCATIVA AURELIO MARTÍNEZ MUTIS',
    'COL NUESTRA SEÂ¿ORA DEL ROSARIO': 'COL NUESTRA SEÑORA DEL ROSARIO',
    'INSTITUCIÃ“N EDUCATIVA JESÃšS LEÃ“N GUERRERO': 'INSTITUCIÓN EDUCATIVA JESÚS LEÓN GUERRERO',
    'INSTITUCION EDUCATIVA LA DIVINA PASTORA': 'INSTITUCIÓN EDUCATIVA LA DIVINA PASTORA',
    'INSTITUCION EDUCATIVA ESCUELA NORMAL SUPERIOR CRISTO REY': 'INSTITUCIÓN EDUCATIVA ESCUELA NORMAL SUPERIOR CRISTO REY',
    'INSTITUTO TÃ‰CNICO AGROPECUARIO RAFAEL ORTIZ GONZALEZ': 'INSTITUTO TÉCNICO AGROPECUARIO RAFAEL ORTIZ GONZÁLEZ',
    'INSTITUCION EDUCTIVA SAN RAFAEL DE CHUCURI': 'INSTITUCIÓN EDUCATIVA SAN RAFAEL DE CHUCURÍ',
    'COLEGIO DE LA PRESENTACION': 'COLEGIO DE LA PRESENTACIÓN',
    'COLEGIO INTEGRADO PEDRO SANTOS': 'COLEGIO INTEGRADO PEDRO SANTOS',
    'INSTITUTO TECNICO PATIOS CENTRO 2': 'INSTITUTO TÉCNICO PATIOS CENTRO 2',
    'INSTITUCIÃ“N EDUCATIVA PITIGUAO': 'INSTITUCIÓN EDUCATIVA PITIGUAO',
    'INSTITUCION EDUCATIVA INSTITUTO TECNICO EN COMUNICACION BARRANCABERMEJA': 'INSTITUCIÓN EDUCATIVA INSTITUTO TÉCNICO EN COMUNICACIÓN BARRANCABERMEJA',
    'INSTITUCIÃ“N EDUCATIVA CLUB UNIÃ“N': 'INSTITUCIÓN EDUCATIVA CLUB UNIÓN',
    'INSTITUCION EDUCATIVA EL CRUCE DE SANTA ROSA': 'INSTITUCIÓN EDUCATIVA EL CRUCE DE SANTA ROSA',
    'INSTITUCION EDUCATIVA  POZO NUTRIAS DOS': 'INSTITUCIÓN EDUCATIVA POZO NUTRIAS DOS',
    'INSTITUCION EDUCATIVA ESCUELA NORMAL SUPERIOR': 'INSTITUCIÓN EDUCATIVA ESCUELA NORMAL SUPERIOR',
    'INSTITUCIÃ“N EDUCATIVA GALAPAGOS': 'INSTITUCIÓN EDUCATIVA GALÁPAGOS',
    'INSTITUCION EDUCATIVA COLEGIO MARTA': 'INSTITUCIÓN EDUCATIVA COLEGIO MARTA',
    'COLEGIO INTEGRADO CAMACHO CARREÃ‘O': 'COLEGIO INTEGRADO CAMACHO CARREÑO',
    'INSTITUCION EDUCATIVA  EL CERRO': 'INSTITUCIÓN EDUCATIVA EL CERRO',
    'COLEGIO NUESTRA SEÃ‘ORA DE FATIMA': 'COLEGIO NUESTRA SEÑORA DE FÁTIMA',
    'INSTITUCION EDUCATIVA  SAN IGNACIO': 'INSTITUCIÓN EDUCATIVA SAN IGNACIO',
    'INSTITUCION EDUCATIVA COLEGIO PORTAL CAMPESTRE NORTE': 'INSTITUCIÓN EDUCATIVA COLEGIO PORTAL CAMPESTRE NORTE',
    'COLEGIO NUESTRA SEÃ‘ORA DEL ROSARIO': 'COLEGIO NUESTRA SEÑORA DEL ROSARIO',
    'INSTITUCION EDUCATIVA VILLAS DE SAN JUAN': 'INSTITUCIÓN EDUCATIVA VILLAS DE SAN JUAN',
    'INSTITUCION EDUCATIVA NUESTRA SEÃ‘ORA DEL PILAR': 'INSTITUCIÓN EDUCATIVA NUESTRA SEÑORA DEL PILAR',
    'INSTITUCION EDUCATIVA COLEGIO SANTA CRUZ': 'INSTITUCIÓN EDUCATIVA COLEGIO SANTA CRUZ',
    'INSTITUCION EDUCATIVA COLEGIO NUESTRA SEÃ‘ORA DE BELEN': 'INSTITUCIÓN EDUCATIVA COLEGIO NUESTRA SEÑORA DE BELÉN',
    'COLEGIO SAN JOSÃ‰': 'COLEGIO SAN JOSÉ',
    'INST EDUCATIVA COL NUESTRA SEÃ‘ORA DEL ROSARIO': 'INST EDUCATIVA COL NUESTRA SEÑORA DEL ROSARIO',
    'INSTITUCIÃ“N EDUCATIVA  EL MORRO': 'INSTITUCIÓN EDUCATIVA EL MORRO',
    'INSTITUCION EDUCATIVA  EL RUBI': 'INSTITUCIÓN EDUCATIVA EL RUBÍ',
    'INSTITUCION EDUCATIVA SAN JUAN BOSCO CAÃ‘AVERAL': 'INSTITUCIÓN EDUCATIVA SAN JUAN BOSCO CAÑAVERAL',
    'INST ARQUIDIOCESANO SAN FRANCISCO DE ASIS': 'INST ARQUIDIOCESANO SAN FRANCISCO DE ASÍS',
    'COL SAGRADO CORAZON DE JESUS HERMANAS BETHLEMITAS': 'COL SAGRADO CORAZÓN DE JESÚS HERMANAS BETHLEMITAS',
    'INSTITUCIÃ“N EDUCATIVA RAFAEL GARCÃ\x8dA HERREROS': 'INSTITUCIÓN EDUCATIVA RAFAEL GARCÍA HERREROS',
    'COLEGIO  LAS MONTOYAS': 'COLEGIO LAS MONTOYAS',
    'INSTITUCION EDUCATIVA JORGE ARDILA DUARTE': 'INSTITUCIÓN EDUCATIVA JORGE ARDILA DUARTE',
    'INSTITUCION EDUCATIVA COLEGIO GENERAL SANTANDER': 'INSTITUCIÓN EDUCATIVA COLEGIO GENERAL SANTANDER',
    'COLEGIO LUIS CARLOS GALÃ\x81N SARMIENTO': 'COLEGIO LUIS CARLOS GALÁN SARMIENTO',
    'INSTITUCION EDUCATIVA  SAN ISIDRO': 'INSTITUCIÓN EDUCATIVA SAN ISIDRO',
    'INSTITUCION EDUCATIVA COLEGIO GUILLERMO QUINTERO CALDERON': 'INSTITUCIÓN EDUCATIVA COLEGIO GUILLERMO QUINTERO CALDERÓN',
    'COLEGIO INTEGRADO ALFONSO GOMEZ GOMEZ': 'COLEGIO INTEGRADO ALFONSO GÓMEZ GÓMEZ',
    'INSTITUCION EDUCATIVA CAMBRIDGE SCHOOL': 'INSTITUCIÓN EDUCATIVA CAMBRIDGE SCHOOL',
    'INST JOSE CELESTINO MUTIS': 'INST JOSÉ CELESTINO MUTIS',
    'COLEGIO NUESTRA SEÃ‘ORA DE LA SALUD': 'COLEGIO NUESTRA SEÑORA DE LA SALUD',
    'COLEGIO NUESTRA SEÃ‘ORA DE LA PAZ': 'COLEGIO NUESTRA SEÑORA DE LA PAZ',
    'COLEGIO INTEGRADO NUESTRA SEÃ‘ORA DE LAS MERCEDES': 'COLEGIO INTEGRADO NUESTRA SEÑORA DE LAS MERCEDES',
    'COLEGIO SAN JOSÃ‰ DE MOTOSO': 'COLEGIO SAN JOSÉ DE MOTOSO',
    'INSTITUCION EDUCATIVA COLEGIO NUESTRA SEÃ‘ORA DE BELEN': 'INSTITUCIÓN EDUCATIVA COLEGIO NUESTRA SEÑORA DE BELÉN'
    # Agregar más reemplazos si es necesario
}

# Reemplazar los valores mal codificados
df['COLE_NOMBRE_ESTABLECIMIENTO'] = df['COLE_NOMBRE_ESTABLECIMIENTO'].replace(replacements)

# Verificar los valores únicos después de la corrección
print("Valores únicos en 'COLE_NOMBRE_ESTABLECIMIENTO' después de la corrección:")
print(df['COLE_NOMBRE_ESTABLECIMIENTO'].unique())
# Out:
# Valores únicos en 'COLE_NOMBRE_ESTABLECIMIENTO' después de la corrección:
# ['IE NUESTRA SEÑORA DEL PILAR' 'COLEGIO  LUIS A. CALVO'
#  'INSTITUCION EDUCATIVA EL RESGUARDO' 'INST TECNICO MARIA INMACULADA'
#  'COL LUIS GABRIEL CASTRO' 'COL GONZALO JIMENEZ NAVAS'
#  'COLEGIO INTEGRADO EDUARDO CAMACHO GAMBA' 'COLEGIO  AGUADA DE CEFERINO'
#  'COLEGIO SAN JUAN DE GIRON' 'COL CAMPESTRE GOYAVIER'
#  'COLEGIO  LLANO DE PALMAS' 'INST INTEGD SAN BERNARDO'
#  'CENTRO EDUCATIVO JORGE ELIECER GAITAN' 'I.E. JUAN PABLO I'
#  'COLEGIO MUNICIPAL MARÍA CONCEPCIÓN LOPERENA'
#  'COLEGIO NIEVES CORTES PICON' 'INST TECNICO INDUSTRIAL LUCIO PABON NUÑEZ'
#  'IE TEC DAMASO ZAPATA' 'COL TEC VICENTE AZUERO'
#  'COL INTEGRADO NUESTRA SEÑORA DE LAS ANGUSTIAS'
#  'COLEGIO INTEGRADO CAMILO TORRES'
#  'INSTITUTO POLITECNICO MONSEÑOR MANUEL SORZANO GONZALEZ'
#  'INST TEC COLOMBIANO INTECOL' 'COL LOS SANTOS APOSTOLES' 'FUND COL UIS'
#  'INSTITUTO TECNICO INDUSTRIAL MONSEÃ‘OR CARLOS ARDILA GARCIA'
# ...

# %%
replacements_sede = {
    'I E NUESTRA SEÂ¾ORA DEL PILAR': 'I E NUESTRA SEÑORA DEL PILAR',
    'INST TECNICO MARIA INMACULADA': 'INST TECNICO MARÍA INMACULADA',
    'COLEGIO ALFONSO LOPEZ': 'COLEGIO ALFONSO LÓPEZ',
    'INST TECNICO INDUSTRIAL LUCIO PABON NUÃ‘EZ': 'INST TECNICO INDUSTRIAL LUCIO PABON NUÑEZ',
    'INSTITUTO POLITECNICO MONSEÃ‘OR MANUEL SORZANO GONZALEZ': 'INSTITUTO POLITECNICO MONSEÑOR MANUEL SORZANO GONZALEZ',
    'INST TEC COLOMBIANO INTECOL': 'INST TEC COLOMBIANO INTECOL',
    'COL LOS SANTOS APOSTOLES': 'COL LOS SANTOS APÓSTOLES',
    'INSTITUTO TECNICO INDUSTRIAL MONSEÃ‘OR CARLOS ARDILA GARCIA': 'INSTITUTO TECNICO INDUSTRIAL MONSEÑOR CARLOS ARDILA GARCÍA',
    'COL DEL SAGRADO CORAZON DE JESUS': 'COL DEL SAGRADO CORAZÓN DE JESÚS',
    'COLEGIO ISIDRO CABALLERO DELGADO': 'COLEGIO ISIDRO CABALLERO DELGADO',
    'COLEGIO TECNICO INDUSTRIAL JOSE ELIAS PUYANA': 'COLEGIO TECNICO INDUSTRIAL JOSÉ ELÍAS PUYANA',
    'COL JOSE EUSEBIO CARO': 'COL JOSÉ EUSEBIO CARO',
    'COLEGIO ALFONSO LOPEZ': 'COLEGIO ALFONSO LÓPEZ',
    'INSTITUTO TECNICO INDUSTRIAL EMETERIO DUARTE SUAREZ': 'INSTITUTO TECNICO INDUSTRIAL EMETERIO DUARTE SUÁREZ',
    'COL GONZALO RIVERA LAGUADO': 'COL GONZALO RIVERA LAGUADO',
    'INSTITUTO LUIS CARLOS GALAN SARMIENTO DEL SUR': 'INSTITUTO LUIS CARLOS GALÁN SARMIENTO DEL SUR',
    'I.E. COLEGIO NIEVES CORTES PICON SEDE A - SEDE PRINCIPAL': 'I.E. COLEGIO NIEVES CORTÉS PICÓN SEDE A - SEDE PRINCIPAL',
    'INST TECNICO INDUSTRIAL LUCIO PABON NUÃ‘EZ': 'INST TECNICO INDUSTRIAL LUCIO PABÓN NUÑEZ',
    'COL CAMPESTRE GOYAVIER': 'COL CAMPESTRE GOYAVIER',
    'INSTITUTO DE PROMOCION SOCIAL': 'INSTITUTO DE PROMOCIÓN SOCIAL',
    'COLEGIO SAN JUAN DE GIRON': 'COLEGIO SAN JUAN DE GIRÓN',
    'ATLANTIS SYSTEM - SEDE PRINCIPAL': 'ATLANTIS SYSTEM - SEDE PRINCIPAL',
    'COLEGIO TECNICO INDUSTRIAL JOSE ELIAS PUYANA': 'COLEGIO TÉCNICO INDUSTRIAL JOSÉ ELÍAS PUYANA',
    'I E NUESTRA SEÃ‘ORA DEL PILAR SEDE B': 'I E NUESTRA SEÑORA DEL PILAR SEDE B',
    'INSTITUCION EDUCATIVA COLEGIO NUESTRA SEÃ‘ORA DE BELEN': 'INSTITUCIÓN EDUCATIVA COLEGIO NUESTRA SEÑORA DE BELÉN',
    'INSTITUCION EDUCATIVA NUESTRA SEÃ‘ORA DE FÃTIMA': 'INSTITUCIÓN EDUCATIVA NUESTRA SEÑORA DE FÁTIMA',
    'I E NUESTRA SEÃ‘ORA DEL PILAR': 'I E NUESTRA SEÑORA DEL PILAR',
    'COL CLUB DE LEONES': 'COL CLUB DE LEONES',
    'INST TEC NAL DE COMERCIO': 'INST TEC NAL DE COMERCIO',
    'INST SALESIANO SAN JUAN BOSCO': 'INST SALESIANO SAN JUAN BOSCO',
    'COL LA PRESENTACION': 'COL LA PRESENTACIÓN',
    'IE INTEGRADOD JORGE ELIECER GAITAN': 'IE INTEGRADOD JORGE ELIECER GAITÁN',
    'INSTITUTO POLITENCIO JOSE CELESTINO MUTIS - SEDE PRINCIPAL': 'INSTITUTO POLITENCIO JOSÉ CELESTINO MUTIS - SEDE PRINCIPAL',
    'COL PABLO NERUDA': 'COL PABLO NERUDA',
    'COLEGIO NUESTRA SEÃ‘ORA DE LA SALUD': 'COLEGIO NUESTRA SEÑORA DE LA SALUD',
    'COLEGIO NUESTRA SEÃ‘ORA DE LA PAZ': 'COLEGIO NUESTRA SEÑORA DE LA PAZ',
    'COLEGIO INTEGRADO NUESTRA SEÃ‘ORA DE LAS MERCEDES': 'COLEGIO INTEGRADO NUESTRA SEÑORA DE LAS MERCEDES',
    'COLEGIO SAN JOSÃ‰ DE MOTOSO': 'COLEGIO SAN JOSÉ DE MOTOSO',
    'COL MANUEL ANTONIO FERNANDEZ DE NOVOA': 'COL MANUEL ANTONIO FERNÁNDEZ DE NOVOA',
    'COL AGUEDA GALLARDO DE VILLAMIZAR': 'COL ÁGUEDA GALLARDO DE VILLAMIZAR',
    'INSTITUTO AGRICOLA - SEDE PRINCIPAL': 'INSTITUTO AGRÍCOLA - SEDE PRINCIPAL',
    'COLEGIO SAN JUAN NEPOMUCENO': 'COLEGIO SAN JUAN NEPOMUCENO',
    'I.E. EL DIAMANTE - SEDE PRINCIPAL': 'I.E. EL DIAMANTE - SEDE PRINCIPAL',
    'COLEGIO RAFAEL URIBE URIBE - SEDE PRINCIPAL': 'COLEGIO RAFAEL URIBE URIBE - SEDE PRINCIPAL',
    'COLEGIO DE LA PRESENTACION SANTA TERESA - CUCUTA': 'COLEGIO DE LA PRESENTACIÓN SANTA TERESA - CÚCUTA',
    'COLEGIO NUESTRA SEÃ‘ORA DE FATIMA - SEDE PRINCIPAL': 'COLEGIO NUESTRA SEÑORA DE FÁTIMA - SEDE PRINCIPAL',
    'COLEGIO GRAN MARISCAL DE AYACUCHO': 'COLEGIO GRAN MARISCAL DE AYACUCHO',
    'COLEGIO JESUS ANTONIO RAMIREZ': 'COLEGIO JESÚS ANTONIO RAMIREZ',
    'COLEGIO NUESTRA SEÃ‘ORA DE LA CONCEPCION': 'COLEGIO NUESTRA SEÑORA DE LA CONCEPCIÓN',
    'COLEGIO NUESTRA SEÃ‘ORA DEL PILAR - SEDE PRINCIPAL': 'COLEGIO NUESTRA SEÑORA DEL PILAR - SEDE PRINCIPAL',
    'INSTITUCION EDUCATIVA CAMACHO CARREÃ‘O': 'INSTITUCIÓN EDUCATIVA CAMACHO CARREÑO',
    'INSTITUCION EDUCATIVA  LA PLAZUELA': 'INSTITUCIÓN EDUCATIVA LA PLAZUELA',
    'COLEGIO INTEGRADO CAMACHO CARREÃ‘O': 'COLEGIO INTEGRADO CAMACHO CARREÑO',
    'INSTITUCION EDUCATIVA SAN JUAN BOSCO CAÃ‘AVERAL': 'INSTITUCIÓN EDUCATIVA SAN JUAN BOSCO CAÑAVERAL',
    'INSTITUTO TECNICO AGROINDUSTRAIL DE EDUCACION CAMPESINA': 'INSTITUTO TÉCNICO AGROINDUSTRIAL DE EDUCACIÓN CAMPESINA',
    'INSTITUCION EDUCATIVA VERSALLES': 'INSTITUCIÓN EDUCATIVA VERSALLES',
    'INSTITUTO TECNICO AGROINDUSTRAIL DE EDUCACION CAMPESINA': 'INSTITUTO TÉCNICO AGROINDUSTRIAL DE EDUCACIÓN CAMPESINA',
    'COLEGIO DEPARTAMENTAL INTEGRADO NUESTRA SEÃ‘ORA DE LOURDES': 'COLEGIO DEPARTAMENTAL INTEGRADO NUESTRA SEÑORA DE LOURDES',
    'INSTITUCION EDUCATIVA NUESTRA SEÃ‘ORA DE FÃTIMA': 'INSTITUCIÓN EDUCATIVA NUESTRA SEÑORA DE FÁTIMA',
    'COLEGIO SANTA CRUZ DE LA NUEVA BAEZA': 'COLEGIO SANTA CRUZ DE LA NUEVA BAEZA',
    'INSTITUCION EDUCATIVA QUEBRADAS': 'INSTITUCIÓN EDUCATIVA QUEBRADAS',
    'COLEGIO SANTO ANGEL': 'COLEGIO SANTO ÁNGEL',
    'INSTITUTO VALLE DE RUITOQUE': 'INSTITUTO VALLE DE RUITOQUE',
    'INSTITUTO TECNICO AGRICOLA': 'INSTITUTO TÉCNICO AGRÍCOLA',
    'COLEGIO NUESTRA SEÃ‘ORA DEL PILAR': 'COLEGIO NUESTRA SEÑORA DEL PILAR',
    'COLEGIO SANTO DOMINGO SAVIO': 'COLEGIO SANTO DOMINGO SAVIO',
    'INST SALESIANO SAN JUAN BOSCO': 'INST SALESIANO SAN JUAN BOSCO',
    'COLEGIO NUESTRA SEÃ‘ORA DE FATIMA': 'COLEGIO NUESTRA SEÑORA DE FÁTIMA',
    'COLEGIO GRAN MARISCAL DE AYACUCHO': 'COLEGIO GRAN MARISCAL DE AYACUCHO',
    'COLEGIO NUESTRA SEÃ‘ORA DEL PILAR': 'COLEGIO NUESTRA SEÑORA DEL PILAR',
    'COLEGIO NUESTRA SEÃ‘ORA DE FATIMA': 'COLEGIO NUESTRA SEÑORA DE FÁTIMA',
}

# Reemplazar valores en la columna 'COLE_NOMBRE_SEDE'
df['COLE_NOMBRE_SEDE'] = df['COLE_NOMBRE_SEDE'].replace(replacements_sede)

# Eliminar filas con valores nulos en la columna 'COLE_NOMBRE_SEDE'
df = df.dropna(subset=['COLE_NOMBRE_SEDE'])

# %%
# Eliminar filas con valores nulos en la columna 'ESTU_GENERO'
df = df.dropna(subset=['ESTU_GENERO'])

# Verificar el resultado
print(df['ESTU_GENERO'].unique())
# Out:
# ['F' 'M']

# %%
num_rows = df.shape[0]
print(f"Número de filas: {num_rows}")
# Out:
# Número de filas: 141396

# %%
# Eliminar filas con valores nulos en la columna 'FAMI_CUARTOSHOGAR'
df = df.dropna(subset=['FAMI_CUARTOSHOGAR'])

# Verificar el resultado
print(df['FAMI_CUARTOSHOGAR'].unique())
# Out:
# ['Tres' 'Uno' 'Seis o mas' 'Cuatro' 'Dos' 'Cinco']

# %%
num_rows = df.shape[0]
print(f"Número de filas: {num_rows}")
# Out:
# Número de filas: 136818

# %%
replacements_madre = {
    'EducaciÃ³n profesional incompleta': 'Educación profesional incompleta',
    'Primaria incompleta': 'Primaria incompleta',
    'Secundaria (Bachillerato) completa': 'Secundaria completa',
    'Secundaria (Bachillerato) incompleta': 'Secundaria incompleta',
    'TÃ©cnica o tecnolÃ³gica completa': 'Técnica o tecnológica completa',
    'Primaria completa': 'Primaria completa',
    'EducaciÃ³n profesional completa': 'Educación profesional completa',
    'Ninguno': 'Ninguno',
    'Postgrado': 'Postgrado',
    'TÃ©cnica o tecnolÃ³gica incompleta': 'Técnica o tecnológica incompleta'
}

# Reemplazar valores en la columna 'FAMI_EDUCACIONMADRE'
df['FAMI_EDUCACIONMADRE'] = df['FAMI_EDUCACIONMADRE'].replace(replacements_madre)

# Eliminar filas con valores 'No sabe' y 'No Aplica' en la columna 'FAMI_EDUCACIONMADRE'
df = df[~df['FAMI_EDUCACIONMADRE'].isin(['No sabe', 'No Aplica'])]

# Eliminar filas con valores nulos en la columna 'FAMI_EDUCACIONMADRE'
df = df.dropna(subset=['FAMI_EDUCACIONMADRE'])

# Verificar el resultado
print(df['FAMI_EDUCACIONMADRE'].unique())
# Out:
# ['Educación profesional incompleta' 'Primaria incompleta'
#  'Secundaria completa' 'Secundaria incompleta'
#  'Técnica o tecnológica completa' 'Primaria completa'
#  'Educación profesional completa' 'Postgrado' 'Ninguno'
#  'Técnica o tecnológica incompleta']

# %%
replacements_padre = {
    'Secundaria (Bachillerato) completa': 'Secundaria completa',
    'Primaria incompleta': 'Primaria incompleta',
    'Secundaria (Bachillerato) incompleta': 'Secundaria incompleta',
    'EducaciÃ³n profesional completa': 'Educación profesional completa',
    'Primaria completa': 'Primaria completa',
    'TÃ©cnica o tecnolÃ³gica incompleta': 'Técnica o tecnológica incompleta',
    'Ninguno': 'Ninguno',
    'TÃ©cnica o tecnolÃ³gica completa': 'Técnica o tecnológica completa',
    'EducaciÃ³n profesional incompleta': 'Educación profesional incompleta',
    'Postgrado': 'Postgrado'
}

# Reemplazar valores en la columna 'FAMI_EDUCACIONPADRE'
df['FAMI_EDUCACIONPADRE'] = df['FAMI_EDUCACIONPADRE'].replace(replacements_padre)

# Eliminar filas con valores 'No sabe' y 'No Aplica' en la columna 'FAMI_EDUCACIONPADRE'
df = df[~df['FAMI_EDUCACIONPADRE'].isin(['No sabe', 'No Aplica'])]

# Eliminar filas con valores nulos en la columna 'FAMI_EDUCACIONPADRE'
df = df.dropna(subset=['FAMI_EDUCACIONPADRE'])

# Verificar el resultado
print(df['FAMI_EDUCACIONPADRE'].unique())
# Out:
# ['Secundaria completa' 'Primaria incompleta' 'Secundaria incompleta'
#  'Educación profesional completa' 'Primaria completa'
#  'Técnica o tecnológica incompleta' 'Técnica o tecnológica completa'
#  'Ninguno' 'Educación profesional incompleta' 'Postgrado']

# %%
num_rows = df.shape[0]
print(f"Número de filas: {num_rows}")
# Out:
# Número de filas: 121079

# %%
# Reemplazos para 'FAMI_PERSONASHOGAR'
replacements_personas_hogar = {
    '9 o mÃ¡s': '9 o más'
}

# Aplicar reemplazos en las columnas respectivas
df['FAMI_PERSONASHOGAR'] = df['FAMI_PERSONASHOGAR'].replace(replacements_personas_hogar)

# Eliminar filas con valores nulos en las columnas especificadas
columns_to_clean = [
    'FAMI_ESTRATOVIVIENDA', 'FAMI_PERSONASHOGAR', 'FAMI_TIENEAUTOMOVIL',
    'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET', 'FAMI_TIENELAVADORA'
]
df = df.dropna(subset=columns_to_clean)

# Verificar el resultado
for column in columns_to_clean:
    print(f"{column}: {df[column].unique()}")
# Out:
# FAMI_ESTRATOVIVIENDA: ['Estrato 3' 'Estrato 1' 'Estrato 2' 'Estrato 5' 'Estrato 4' 'Sin Estrato'
#  'Estrato 6']
# FAMI_PERSONASHOGAR: ['3 a 4' '5 a 6' '7 a 8' '9 o más' '1 a 2']
# FAMI_TIENEAUTOMOVIL: ['No' 'Si']
# FAMI_TIENECOMPUTADOR: ['Si' 'No']
# FAMI_TIENEINTERNET: ['Si' 'No']
# FAMI_TIENELAVADORA: ['Si' 'No']

# %%
num_rows = df.shape[0]
print(f"Número de filas: {num_rows}")
# Out:
# Número de filas: 119236

# %% [markdown]
# Convertir a csv para exploración

# %%
df.to_csv('data_limpieza.csv',index=False)
